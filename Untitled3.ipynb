# %% [markdown]
# <a href="https://colab.research.google.com/github/thiruvarasis2204-dot/Thiruvarasi.s/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Data[1] (1).csv")

# %%
df.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df.tail()
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
print('missing values in df \n',df.isnull().sum())
# Out:
# missing values in df
#  Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df_drop = df.dropna()
print('after deleting missing value\n',df_drop.isnull().sum())
# Out:
# after deleting missing value
#  Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
df_fill_const = df.fillna("unknown")
print('After filling missing values\n',df_fill_const.isnull().sum())
# Out:
# After filling missing values
#  Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
df_fill_const = df.fillna("unknown")
print('After filling missing values\n',df_fill_const.head())
# Out:
# After filling missing values
#     Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  unknown       Yes

# %%
df_fill_mean = df.fillna(df.mean(numeric_only=True))
print('After filling missing values\n',df_fill_mean.head())
# Out:
# After filling missing values
#     Country   Age        Salary Purchased
# 0   France  44.0  72000.000000        No
# 1    Spain  27.0  48000.000000       Yes
# 2  Germany  30.0  54000.000000        No
# 3    Spain  38.0  61000.000000        No
# 4  Germany  40.0  63777.777778       Yes

# %%
df_fill_mean.describe()
# Out:
#              Age        Salary
# count  10.000000     10.000000
# mean   38.777778  63777.777778
# std     7.253777  11564.099406
# min    27.000000  48000.000000
# 25%    35.500000  55000.000000
# 50%    38.388889  62388.888889
# 75%    43.000000  70750.000000
# max    50.000000  83000.000000
